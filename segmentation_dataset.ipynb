# %%
import numpy as np 
import matplotlib.pylab as plt 
import scipy.io
import cv2
import matplotlib.pyplot as plt
import numpy as np
import torch
from loguru import logger
from matplotlib.colors import TABLEAU_COLORS
from scipy.ndimage.morphology import binary_fill_holes
from skimage.segmentation import watershed
from torch import nn
from torch.nn import functional as F
mat_file_name = "../../data/segmentation/consep/Train/Labels/train_10.mat"
mat_file = scipy.io.loadmat(mat_file_name)
# Out:
# /tmp/ipykernel_2272059/2728952914.py:10: DeprecationWarning: Please import `binary_fill_holes` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   from scipy.ndimage.morphology import binary_fill_holes

# %%
plt.imshow(hv_mask[1], cmap = 'coolwarm')
