# %%
import math
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.optimizers import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.losses import *
from tqdm.notebook import tqdm
import tensorflow.keras.backend as K
import matplotlib.pyplot as plt
import tensorflow_addons as tfa
import numpy.random as npr
import os, time, gc, random
import glob
import PIL
from tqdm.auto import tqdm
os.environ["CUDA_VISIBLE_DEVICES"] = "4"
# Out:
# 2024-08-13 13:07:53.563992: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-08-13 13:07:54.319389: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/gil/anaconda3/envs/LeeYS/lib/python3.9/site-packages/tensorflow_addons/utils/tfa_eol_msg.py:23: UserWarning:
#
# TensorFlow Addons (TFA) has ended development and introduction of new features.
# TFA has entered a minimal maintenance and release mode until a planned end of life in May 2024.
# Please modify downstream libraries to take dependencies from other repositories in our TensorFlow community (e.g. Keras, Keras-CV, and Keras-NLP).
#
# For more information see: https://github.com/tensorflow/addons/issues/2807
#
#   warnings.warn(

# %% [markdown]
# Layer

# %%
# blocks used in GAN

def minibatchStd(inputs):
    inputs = tf.transpose(inputs, (0, 3, 1, 2)) # NHWC -> NCHW
    group_size = tf.minimum(4, tf.shape(inputs)[0])             # Minibatch must be divisible by (or smaller than) group_size.
    s = inputs.shape                                             # [NCHW]  Input shape.
    y = tf.reshape(inputs, [group_size, -1, 1, s[1], s[2], s[3]])   # [GMncHW] Split minibatch into M groups of size G. Split channels into n channel groups c.
    y -= tf.reduce_mean(y, axis=0, keepdims=True)           # [GMncHW] Subtract mean over group.
    y = tf.reduce_mean(tf.square(y), axis=0)                # [MncHW]  Calc variance over group.
    y = tf.sqrt(y + eps)                                    # [MncHW]  Calc stddev over group.
    y = tf.reduce_mean(y, axis=[2,3,4], keepdims=True)      # [Mn111]  Take average over fmaps and pixels.
    y = tf.reduce_mean(y, axis=[2])                         # [Mn11] Split channels into c channel groups
    y = tf.tile(y, [group_size, 1, s[2], s[3]])             # [NnHW]  Replicate over group and pixels.
    y = tf.concat([inputs, y], axis=1)                        # [NCHW]  Append as new fmap.
    y = tf.transpose(y, (0, 2, 3, 1)) # NCHW -> NHWC
    return y

class DiffUS(tf.keras.layers.Layer):
    def __init__(self):
        return super().__init__()
    
    def call(self, inputs):
        _N, H, W, C = inputs.shape.as_list()
        x = K.reshape(inputs, (-1, H, 1, W, 1, C))
        x = tf.tile(x, (1, 1, 2, 1, 2, 1))
        used = K.reshape(x, (-1, H * 2, W * 2, C))
        return used

def crop_to_fit(x):
    noise, img = x
    height = img.shape[1]
    width = img.shape[2]
    
    return noise[:, :height, :width, :]

ndist = tf.random_normal_initializer(0, 1)
zeros = tf.zeros_initializer()
ones = tf.ones_initializer()

class FCE(Dense): # fully connected equalized
    def __init__(self, units, kernel_initializer=ndist, bias_initializer=zeros, lrelu=True, *args, **kwargs):
        super().__init__(units, *args, **kwargs)
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer
        self.lrelu = lrelu
        self.scale = 1

    def build(self, input_shape):
        super().build(input_shape)
        #print('fce', input_shape)
        n = input_shape[-1] # input_shape = (None, features_in) or (None, dimY, dimX, features_in)
        if self.lrelu:
            self.scale = np.sqrt((1 / 0.6) / n) # he but not really, 1 / 0.6 since lrelu(0.2) makes scales variance to 0.6 (0.2 if neg, 1 if pos, div by 2) and you want them to be 1
        else:
            self.scale = np.sqrt(1 / n)

    def call(self, inputs):
        output = K.dot(inputs, self.kernel * self.scale)
        if self.use_bias:
            output = K.bias_add(output, self.bias)
        if self.activation is not tf.keras.activations.linear:
            output = self.activation(output)
        elif self.lrelu:
            output = LeakyReLU(alpha=0.2)(output)
        return output

    def get_config(self):
        config = super().get_config()
        config.update({
            'kInit': self.kernel_initializer,
            'bInit': self.bias_initializer,
            'scale': self.scale,
            'useLReLU': self.lrelu,
                      })
        return config

class CVE(Conv2D):
    def __init__(self, units, kernel_size=3, kernel_initializer=ndist, bias_initializer=zeros, padding='same', lrelu=True, *args, **kwargs):
        super().__init__(units, kernel_size, *args, **kwargs)
        self.kernel_initializer = kernel_initializer
        self.bias_initializer = bias_initializer
        self.padding = padding
        self.lrelu = lrelu
        self.scale = 1

    def build(self, input_shape):
        super().build(input_shape)
        #print('cve', self.kernel.shape)
        n = np.prod(self.kernel.shape[:-1]) # self.kernel.shape = (kernel_x, kernel_y, features_in, features_out)
        if self.lrelu: # he
            self.scale = np.sqrt((1 / 0.6) / n)
        else:
            self.scale = np.sqrt(1 / n)


    def call(self, inputs):
        output = K.conv2d(inputs, self.kernel * self.scale, padding=self.padding)
        if self.use_bias:
            output = K.bias_add(output, self.bias)
        if self.activation is not tf.keras.activations.linear:
            output = self.activation(output)
        elif self.lrelu:
            output = LeakyReLU(alpha=0.2)(output)
        return output

    def get_config(self):
        config = super().get_config()
        config.update({
            'kInit': self.kernel_initializer,
            'bInit': self.bias_initializer,
            'padding': self.padding,
            'scale': self.scale,
            'useLReLU': self.lrelu,
                      })
        return config

class ConvMod(Layer):
    def __init__(self, nf, x, w, kSize=3, demod=True):
        super().__init__()
        self.nf = nf
        self.kSize = kSize
        self.xShape = x.shape
        self.wShape = w.shape
        self.scale = FCE(self.xShape[-1], bias_initializer=ones, lrelu=False)
        self.conv = CVE(nf, kSize, lrelu=demod)
        self.conv(x) # create kernel without doing it in build method so h5py doesn't go sicko mode
        self.demod = demod

    def build(self, input_shape): # input_shape: [TensorShape([None, 4, 4, 256]), TensorShape([None, 256]), TensorShape([None, 4, 4, 1])]
        super().build(input_shape)

    def call(self, inputs):
        x, w = inputs

        x = tf.transpose(x, (0, 3, 1, 2)) # NHWC -> NCHW
        weight = self.conv.kernel[np.newaxis] * self.conv.scale # kkio -> 1kkio (1, kernel_size, kernel_size, input_features, output_features)

        scale = self.scale(w)
        scale = scale[:, np.newaxis, np.newaxis, :, np.newaxis] # Bs -> B, 1, 1, s, 1 (s - scaling factor)

        wp = weight * scale # 1kkio * B11s1 -> Bkk(s*i)o
        wpp = wp

        if self.demod:
            wStd = tf.math.rsqrt(tf.reduce_sum(tf.math.square(wp), axis=[1,2,3]) + 1e-8) # Bkkio -> Bo
            wpp = wp * wStd[:, np.newaxis, np.newaxis, np.newaxis, :] # [BkkIO] Scale output feature maps.

        x = tf.reshape(x, (1, -1, x.shape[2], x.shape[3])) # N, C, H, W -> 1, (N*C), H, W

        # B, k, k, i, o -> k, k, i, B, o -> k, k, i, (B*o)
        wpp = tf.reshape(tf.transpose(wpp, [1, 2, 3, 0, 4]), [wpp.shape[1], wpp.shape[2], wpp.shape[3], -1])

        x = tf.nn.conv2d(x, wpp, padding='SAME', data_format='NCHW', strides=[1, 1, 1, 1]) # grouped conv
        x = tf.reshape(x, (-1, self.nf, x.shape[2], x.shape[3])) # 1, (N*C), H, W -> N, C, H, W
        x = tf.transpose(x, (0, 2, 3, 1)) # NCHW -> NHWC
        x = K.bias_add(x, self.conv.bias)
        return x

    def get_config(self):
        config = super().get_config()
        config.update({
            'num_filters': self.nf,
            'kernel_size': self.kSize,
            'xShape': self.xShape,
            'wShape': self.wShape,
            'demodulated': self.demod
                      })
        return config

# %% [markdown]
# TimeIt

# %%
# custom class to see how long tasks take
class timeIt:
    def __init__(self, description):
        self.start = time.time()
        self.description = description
        self.running = True
    
    def new(self, description, verbose=True):
        self.start = time.time()
        self.description = description
        
        duration = time.time() - startTime
        if verbose:
            print('{}; {:.4f} seconds to complete'.format(self.description, duration))
        
        return duration
    
    def close(self, verbose=True):
        duration = time.time() - self.start
        if verbose:
            print('{}; {:.4f} seconds to complete'.format(self.description, duration))
            
        self.start = None
        self.description = None
        self.running = False
        return duration

sess = timeIt('testing timer')
time.sleep(0.005)
_ = sess.close(verbose=True)
# Out:
# testing timer; 0.0051 seconds to complete

# %% [markdown]
# Hyperparameters

# %%
# reals - numpy array of the training images; ds - batched TF dataset given to the GPU
datasetPath = '../../data/origin_type/STNT/유형1/*.jpeg'
modelPath = '../../model/styleGAN2/STNT/유형1/'
reals, ds = None, None
gc.collect()

batchSize = 1
m = 2000 # amount of images stored in RAM (reduce if low RAM, increase if high RAM)
m = min(m, int(len(glob.glob(datasetPath))))

m = batchSize * (m // batchSize)
imgSize =1024# size of images in pixels
zdim = imgSize # number of elements in a latent vector
p = 0.0 # probability of data augmentation
n = 1 # number of minibatches before p is changed
numImgsStep = 5e5 # number of images needed to change p from 0 -> 1 or 1 -> 0
pStep = n * batchSize / numImgsStep # how much p increases/decreases per n minibatches
eps = 1e-8 # epsilon, small number used to prevent NaN errors
pplEMA = 0.0 # exponential moving average for average PPL for PPL reg.
discLayerFilters = np.linspace(32,imgSize,int(np.log2(imgSize/4)),dtype=np.int32)
genLayerFilters = np.linspace(imgSize,32,int(np.log2(imgSize/4)),dtype=np.int32)
w1_range=int(np.log2(imgSize/2)/2)
w2_range=int(np.log2(imgSize/2)/2+(np.log2(imgSize/2)%2>=0.5))

# %% [markdown]
# Load data

# %%
AUTO = tf.data.experimental.AUTOTUNE


'''
goes into datasetPath, chooses and stores image data from random files (repeats allowed)
into a np array, converts the array into the TF dataset

Args:
others - random indices for files to choose to train the GAN on
verbose - determines whether duration to complete is printed out or not
'''
def loadData(others=None, verbose=True):
    global reals, ds, m
    sess = timeIt('Loading data')
    reals, ds = None, None
    gc.collect()
    files = glob.glob(datasetPath)
    
    reals = np.zeros((len(files), imgSize, imgSize, 3))
    for i in tqdm(range(len(files))):
        strI = str(files[i])
        img1=PIL.Image.open(strI).convert("RGB")
        img1=np.array(img1)
        reals[i] = img1
        del img1
    
    reals = reals[:m].astype(np.float32)/127.5-1.0

    assert reals.shape[0] % batchSize == 0
    assert type(reals) == np.ndarray
    ds = (tf.data.Dataset.from_tensor_slices(reals).shuffle(3000).batch(batchSize))
    ds = ds.prefetch(AUTO)
    gc.collect()
    sess.close(verbose=verbose)
    
def aug(imgs, p):
    augImgs = imgs
    def augCond(x):
        randInds = tf.random.uniform((batchSize,))
        trueCond = tf.cast(randInds < p, tf.float32) # using tf.cast to turn booleans into ones and zeros
        falseCond = tf.cast(randInds >= p, tf.float32)
        auged = x * tf.reshape(trueCond, (batchSize, 1, 1, 1)) + augImgs * tf.reshape(falseCond, (batchSize, 1, 1, 1))
        return auged
    
    height = tf.random.uniform((), minval=0.5, maxval=1)
    width = tf.random.uniform((), minval=0.5, maxval=1)
    boxLite = tf.random.uniform((batchSize, 2), maxval=(1-height, 1-width))
    boxes = tf.concat([boxLite, tf.transpose(boxLite[:, 0][np.newaxis]) + height, tf.transpose(boxLite[:, 1][np.newaxis]) + width], axis=1)
    boxLiteIso = tf.random.uniform((batchSize, 1), maxval=1-height)
    boxIso = tf.concat([boxLite, tf.transpose(boxLiteIso[:, 0][np.newaxis]) + height, tf.transpose(boxLiteIso[:, 0][np.newaxis]) + height], axis=1)
    rot90s = np.pi * 90 * tf.cast(tf.random.uniform((batchSize,), minval=0, maxval=4, dtype=tf.int32), tf.float32) / 180
    augImgs = augCond(tf.image.random_brightness(augImgs, max_delta=0.25))
    augImgs = augCond(tf.image.crop_and_resize(augImgs, boxIso, tf.range(batchSize), (imgSize, imgSize), extrapolation_value=1))
    augImgs = augCond(tf.image.crop_and_resize(augImgs, boxes, tf.range(batchSize), (imgSize, imgSize), extrapolation_value=1))
    augImgs = augCond(tfa.image.rotate(augImgs, rot90s))
    augImgs = augCond(tfa.image.rotate(augImgs, tf.random.uniform((batchSize,), minval=-np.pi/6, maxval=np.pi/6)))
    augImgs = augCond(tfa.image.translate(augImgs, tf.random.normal((batchSize, 2), 0, imgSize // 10)))
    return augImgs
loadData()
# Out:
#   0%|          | 0/735 [00:00<?, ?it/s]
# 2024-08-13 13:08:13.271281: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 38366 MB memory:  -> device: 0, name: NVIDIA A100-PCIE-40GB, pci bus id: 0000:81:00.0, compute capability: 8.0
# Loading data; 24.5812 seconds to complete

# %% [markdown]
# Layers

# %%
'''
Generator style block.
Args:
accum - accumulated output from the input/output skips
x - the non-RGB image input
w - the style (output of the mapping function with input of the latent vector)
noiseInp - normally distributed noise
filters - number of channels/feature maps the output of the style block will have
us - whether or not to upsample the images
'''
def gblock(accum, x, w, noiseInp, filters, us=True):
    if us:
        x = DiffUS()(x) # using custom upsampling function since other upsampling methods didn't provide gradients of their gradients
        accum = DiffUS()(accum)
    
    for i in range(2):
        x = ConvMod(filters, x, w)([x, w])
        noise = Lambda(crop_to_fit)([noiseInp, x]) # crop noises so it can be added with x
        noise = FCE(filters, kernel_initializer=zeros, use_bias=False, lrelu=False)(noise) #scale noises
        x = Add()([x, noise])
        x = LeakyReLU(alpha=0.2)(x)
    
    trgb = ConvMod(3, x, w, 1, demod=False)([x, w]) # toRGB 1x1 convolution
    accum = Add()([accum, trgb]) * np.sqrt(1 / 2) # the sqrt(1/2) not included in original StyleGAN2 but i didn't see why not
        
    return accum, x

# Discriminator block.
def dblock(x, filters, maxFilters=256):
    frgb = CVE(min(2 * filters, maxFilters), 1, lrelu=False, use_bias=False)(x)
    
    x = CVE(filters)(x)
    x = CVE(min(2 * filters, maxFilters))(x)
        
    frgb = AveragePooling2D()(frgb)
    x = AveragePooling2D()(x)
    x = Add()([x, frgb])
    
    return x

# %% [markdown]
# Build models

# %%
nBlocks = int(np.log2(imgSize / 4)) # number of upsampled style blocks

# mapper architecture
def ztow(nlayers=8):
    z = Input((zdim,))
    w = z
    if nlayers > 0:
        w = LayerNormalization()(w)
    for i in range(max(nlayers-1, 0)):
        w = FCE(zdim)(w)
    return Model(z, w, name='mapping')

# generator architecture
def genGen():
    ws = [Input((zdim,), name='w{}'.format(i)) for i in range(nBlocks+1)]
    noiseInp = Input((imgSize, imgSize, 1), name='noiseInp')

    x = Dense(1)(ws[0]); x = Lambda(lambda x: x * 0 + 1)(x)
    x = FCE(4*4*zdim, lrelu=False, use_bias=False)(x)
    x = Reshape((4, 4, zdim))(x)
    
    
    
    x = ConvMod(genLayerFilters[0], x, ws[0])([x, ws[0]])
    noise = Lambda(crop_to_fit)([noiseInp, x])
    noise = FCE(genLayerFilters[0], kernel_initializer=zeros, use_bias=False, lrelu=False)(noise)
    x = Add()([x, noise])
    x = LeakyReLU(alpha=0.2)(x)
    accum = ConvMod(3, x, ws[0], 1, demod=False)([x, ws[0]])
    
    for idx, f in enumerate(genLayerFilters):
        accum, x = gblock(accum, x, ws[idx+1], noiseInp, f)
        
    out = CVE(3, 1, lrelu=False)(accum)
    return Model([*ws, noiseInp], out, name='generator')
      
# discriminator architecture  
def genDisc():
    inp = Input((imgSize, imgSize, 3)); x = inp

    
    x = CVE(discLayerFilters[0], 1)(x)
    for fi, f in enumerate(discLayerFilters):
        x = dblock(x, f, maxFilters=discLayerFilters[-1])
    
    x = Lambda(minibatchStd)(x)
    x = CVE(discLayerFilters[-1])(x)
    x = Flatten()(x)
    x = FCE(discLayerFilters[-1])(x)
    out = FCE(1, lrelu=False)(x)

    return Model(inp, out, name='discriminator')

# %%
fids, gcosts, dcosts = [], [], []
pplNorms = []
gpcosts = []
ps, rts = [], []


mapper = ztow()
generator = genGen()
discriminator = genDisc()
inception = tf.keras.applications.InceptionV3(include_top=False, pooling='avg', input_shape=(imgSize, imgSize, 3)) # for FID score

# %% [markdown]
# Optimizers and losses

# %%
lr = 2e-3 * batchSize / 32
mapOpt = Adam(lr / 100, epsilon=1e-8)
genOpt = Adam(lr, 0, 0.9, epsilon=1e-8)
discOpt = Adam(lr, 0, 0.9, epsilon=1e-8)

# %%
def rt(truePreds): # overfitting metric
    return tf.reduce_mean(tf.sign(truePreds))

def dra(obsPreds, basePreds): # observe/baseline predictions (representing fake/true data)
    meanBase = K.mean(basePreds)
    return tf.nn.sigmoid(obsPreds - meanBase)

def discLoss(truePreds, fakePreds, epsilon=eps):
    trueLoss = K.mean(tf.nn.softplus(-truePreds)) # -log(sigmoid(real_scores_out))
    fakeLoss = K.mean(tf.nn.softplus(fakePreds)) # -log(1-sigmoid(fake_scores_out))
    classLoss = trueLoss + fakeLoss
    return classLoss

def genLoss(fakePreds, epsilon=eps):
    classLoss = K.mean(tf.nn.softplus(-fakePreds))
    return classLoss

# %% [markdown]
# Regularizers

# %%
# path length reg.
@tf.function
def pplReg(a=0.0):
    pplbatchSize = batchSize // 2
    y = tf.random.normal((pplbatchSize, imgSize, imgSize, 3))
    noise = tf.random.uniform((pplbatchSize, imgSize, imgSize, 1))
    z = tf.random.normal((pplbatchSize, zdim))
    
    w = mapper(z, training=True)
    ws = [w for _ in range(nBlocks+1)]
    preds = generator([*ws, noise], training=True)
    jacLite = tf.math.reduce_sum(preds * y)
    
    jac = tf.gradients(jacLite, w)[0]
    norm = tf.norm(jac)
    return K.mean(tf.square(norm - tf.cast(a, tf.float32))), norm

# %% [markdown]
# FID function

# %%
from scipy.linalg import sqrtm

allRealFeatures = None

# turn TF tensor outputs into numpy array outputs
def toNp(*args):
    ret = []
    for i in args:
        meanVal = i
        try:
            meanVal = i.numpy()
        except:
            pass
        ret.append(meanVal)
    return ret

def calculate_fid():
    global allRealFeatures
    
    def crunch(batch, bs=64):
        z1, z2 = npr.randn(2, bs, zdim)
        noise = npr.randn(bs, imgSize, imgSize, 1)
        w1 = mapper(z1, training=False)
        w2 = mapper(z2, training=False)
        ws = [w1 for _ in range(w1_range)] + [w2 for _ in range(w2_range)]
        fakes = generator([*ws, noise], training=False)
        fakeFeatures = inception(fakes/2+0.5, training=False)
        realFeatures = inception(batch/2+0.5, training=False)
        return fakeFeatures.numpy(), realFeatures.numpy()
    def crunchLite(batch, bs=64):
        z1, z2 = npr.randn(2, bs, zdim)
        noise = npr.randn(bs, imgSize, imgSize, 1)
        w1 = mapper(z1, training=False)
        w2 = mapper(z2, training=False)
        ws = [w1 for _ in range(w1_range)] + [w2 for _ in range(w1_range)]
        fakes = generator([*ws, noise], training=False)
        fakeFeatures = inception(fakes/2+0.5, training=False)
        return fakeFeatures.numpy(), -1
    
    K.clear_session()
    bs = 16
    expandM = bs * (m//bs)
    crunchFunc = crunchLite
    if allRealFeatures is None:
        crunchFunc = crunch
        allRealFeatures = np.zeros((expandM, 2048))
        
    allFakeFeatures = np.zeros((expandM, 2048))
    for batchS in tqdm(range(0, expandM, bs)):
        batch = reals[batchS: batchS + bs]
        fakeFeatures, realFeatures = crunchFunc(batch, bs=bs)
        allFakeFeatures[batchS: batchS + bs] = fakeFeatures
        
        if crunchFunc == crunch:
            allRealFeatures[batchS: batchS + bs] = realFeatures
        
    # calculate mean and covariance statistics
    fakeMean, fakeStd = np.mean(allFakeFeatures, axis=0), np.cov(allFakeFeatures, rowvar=False)
    realMean, realStd = np.mean(allRealFeatures, axis=0), np.cov(allRealFeatures, rowvar=False)
    # calculate sum squared difference between means
    ssdiff = np.sum((fakeMean - realMean) ** 2.0)
    # calculate sqrt of product between cov
    covmean = sqrtm(np.dot(fakeStd, realStd))
    if np.iscomplexobj(covmean):
        covmean = covmean.real
    # calculate score
    fid = ssdiff + np.trace(fakeStd + realStd - 2.0 * covmean)
    K.clear_session()
    return fid

# %% [markdown]
# Step function

# %%
'''
One training step for the GAN.
Args:
batch - input batch of real images
p - probability of augmenting image
pplEMA - skip PPL reg. if it is -1, else use the value for regularization
useGP - skip R1 gradient penalty if it is -1
'''
@tf.function
def trainStep(batch, p, pplEMA=-tf.ones(()), useGP=-tf.ones(())):
    def genImgs():
        z1 = tf.random.normal([batchSize, zdim])
        z2 = tf.random.normal([batchSize, zdim])
        noise = tf.random.normal([batchSize, imgSize, imgSize, 1])

        w1 = z1; w2 = z2
        w1 = mapper(z1, training=True)
        w2 = tf.cond(tf.random.uniform(()) < 0.9, lambda: mapper(z2, training=True), lambda: w1)
        splitInd = npr.randint(nBlocks+1)
        ws = [w1 for _ in range(splitInd)] + [w2 for _ in range(nBlocks+1-splitInd)]
        fakes = generator([*ws, noise], training=True)
        return fakes
    
    fakes = genImgs()
    augBatch = aug(batch, p)
    augFakes = aug(fakes, p)
    truePreds = discriminator(augBatch, training=True)
    fakePreds = discriminator(augFakes, training=True)

    gpWeight = 16 * 10 / 2
    gploss = tf.cond(useGP >= 0, lambda: gpWeight * K.mean((tf.reduce_sum(tf.square(tf.gradients(truePreds, [augBatch])[0]), axis=[1,2,3]))), lambda: 0.0)

    dloss = discLoss(truePreds, fakePreds) + gploss
    rtBatch = rt(truePreds)
    
    fakes = genImgs()
    augFakes = aug(fakes, p)
    fakePreds = discriminator(augFakes, training=True)

    pplWeight = 8 * 2 / (imgSize * imgSize * (nBlocks + 1))
    pplLoss, pplNorm = tf.cond(pplEMA >= 0, lambda: pplReg(pplEMA), lambda: (0.0, 0.0))
    pplLoss = pplWeight * pplLoss
    gloss = genLoss(fakePreds) + pplLoss
    
    dGrad = tf.gradients(dloss, discriminator.trainable_variables)
    discOpt.apply_gradients(zip(dGrad, discriminator.trainable_variables))

    gGrad = tf.gradients(gloss, generator.trainable_variables)
    genOpt.apply_gradients(zip(gGrad, generator.trainable_variables))
    
    mGrad = tf.gradients(gloss, mapper.trainable_variables)
    mapOpt.apply_gradients(zip(mGrad, mapper.trainable_variables))
    
    return dloss, gploss, gloss, rtBatch, pplLoss, pplNorm

# %% [markdown]
# Gradient visualization function

# %%
def retGrads():
    z1 = tf.random.normal([1, zdim])
    z2 = tf.random.normal([1, zdim])
    noise = tf.random.normal([1, imgSize, imgSize, 1])
    randImg = tf.convert_to_tensor(reals[npr.randint(0, reals.shape[0])][np.newaxis])

    with tf.GradientTape() as tapeReal, tf.GradientTape() as tapeFake:
        w1 = z1; w2 = z2
        w1 = mapper(z1, training=False)
        w2 = mapper(z2, training=False)
        ws = [w1 for _ in range(3)] + [w2 for _ in range(4)]
        tapeReal.watch(randImg)
        fakes = generator([*ws, noise], training=False)
        tapeFake.watch(fakes)
        truePreds = discriminator(randImg, training=False)
        fakePreds = discriminator(fakes, training=False)
        dloss = discLoss(truePreds, fakePreds)

    realGrad = tapeReal.gradient(dloss, randImg)[0]
    fakeGrad = tapeFake.gradient(dloss, fakes)[0]
    realNorm = tf.norm(realGrad)
    fakeNorm = tf.norm(fakeGrad)
    return realGrad.numpy(), fakeGrad.numpy(), realNorm.numpy(), fakeNorm.numpy(), randImg[0].numpy(), fakes[0].numpy(), truePreds.numpy(), fakePreds.numpy()

# %% [markdown]
# Train functions

# %%
def train(epochs=None, steps=None, n=4):
    global p, pplNorms, pplEMA
    gc.collect()
    rtBatches = 0
    
    if epochs != None:
        for i in range(epochs):
            gc.collect()
            dcost, gpcost, gcost = 0, 0, 0
            pplSum = 0
            rtSum, pplCost = 0, 0
            batchNum = 0
            for batch in ds:
                pTensor = tf.convert_to_tensor(p, dtype=tf.float32)
                batch = reals[npr.randint(0, m, (batchSize,))]
                if batchNum % 16 == 0:
                    vals = toNp(*trainStep(batch, pTensor, tf.convert_to_tensor(pplEMA), useGP=tf.ones(())))
                elif batchNum % 8 == 0:
                    vals = toNp(*trainStep(batch, pTensor, tf.convert_to_tensor(pplEMA)))
                else:
                    vals = toNp(*trainStep(batch, pTensor))
                dloss, gploss, gloss, rtBatch, pplLoss, pplNorm = vals

                if pplNorm != 0:
                    pplEMA = 0.01 * pplNorm + 0.99 * pplEMA
                
                rtBatches += rtBatch
                if batchNum % n == 0:
                    p += pStep * np.sign(rtBatches/n - 0.6)
                    p = round(min(max(p, 0), 1), 6) % 0.8
                    rtBatches = 0
                batchNum += 1
                dcost += dloss; gpcost += gploss; gcost += gloss; rtSum += rtBatch; pplCost += pplLoss; pplSum += pplNorm
            
            dcosts.append(dcost)
            gcosts.append(gcost)
            gpcosts.append(gpcost)
            pplNorms.append(round(pplSum / batchNum, 4))
            ps.append(p)
            rts.append(rtBatch)
            print('Epoch: {} | D Cost: {} | GP Cost: {} | G Cost: {}'.format(i, dcost, gpcost, gcost), end = ' | ')
            print('P(aug): {} | Rt: {} | PPL Norm: {} | PPL Loss: {}'.format(p, round(rtSum / batchNum, 4), round(pplSum / batchNum, 4), round(pplCost, 4)))

# %% [markdown]
# Display function

# %%
rows, cols = 1, 4

'''
Display generated images as well as a summary of model metrics.
Args:
z1/z2 - latent input vector 1/2
noise - noise input
verbose - 5-element list saying which metrics to calculate and print out
verbose[0] - FID score
verbose[1] - D(G(z)) - discriminator predictions on generated images
verbose[2] - D(x) - discriminator predictions on real images
verbose[3/4] - D/G Loss
verbose=True/1: print everything
verbose=False/0: print nothing
'''

def display(z1, z2, noise, verbose=True):
    gc.collect()
    fig = plt.figure(figsize=(30, 5))
    axes = fig.subplots(rows, cols)
    
    z1[0] = constZ; z2[0] = constZ; noise[0] = constNoise
    assert z1.shape == (rows * cols, zdim)
    assert z2.shape == (rows * cols, zdim)
    assert noise.shape == (rows * cols, imgSize, imgSize, 1)
        
    randInds = npr.randint(0, reals.shape[0], (rows*cols,))
    
    w1 = z1; w2 = z2
    w1 = mapper(z1, training=False)
    w2 = mapper(z2, training=False)
    ws = [w1 for _ in range(w1_range)] + [w2 for _ in range(w2_range)]
    preds = generator([*ws, noise], training=False)
    df = discriminator(preds, training=False)
    dr = discriminator(reals[randInds], training=False)
    if type(verbose) == type(True):
        verbose = [verbose for i in range(5)]
    if type(verbose) == int:
        if verbose == 0:
            verbose = [False for i in range(5)]
        elif verbose == 1:
            verbose = [False, False, False, True, True]
        elif verbose == 2:
            verbose = [False, True, True, True, True]
        elif verbose == 3:
            verbose = [True for i in range(5)]
            
    if verbose[1]:
        print('D(G(z)) (lower = better disc):', np.mean(df))
    if verbose[2]:
        print('D(x) (higher = better disc):', np.mean(dr))
    if verbose[3]:
        print('D Loss:', discLoss(dr, df))
    if verbose[4]:
        print('G Loss:', genLoss(df))
    
    for i in range(rows):
        for j in range(cols):
            axes[j].imshow(preds[i*cols + j] / 2 + 0.5)

    plt.show()
    
    if verbose[0]:
        fid = round(calculate_fid(), 4)
        print('FID:', fid)
        fids.append(fid)
    return preds

# %% [markdown]
# Save model function

# %%
'''
Save current state of model, overwriting past state of model on disk.
Args:
askInp - require user to place input before saving models - protects user from accidentally overwriting models with a collapsed model
'''
def save_models(askInp=True):
    if askInp:
        input()
    
    
    generator.save_weights(modelPath+'genWeights.h5')
    discriminator.save_weights(modelPath+'discWeights.h5')
    mapper.save_weights(modelPath+'mapWeights.h5')

# %% [markdown]
# Train GAN

# %%
constZ = npr.randn(zdim,)
constNoise = npr.randn(imgSize, imgSize, 1)
epoch = 0
if type(reals) != np.ndarray or type(ds) == type(None):
        loadData()
while True:
    sess = timeIt('Training')
    display(z1=npr.randn(rows * cols, zdim), z2=npr.randn(rows * cols, zdim), noise=npr.randn(rows * cols, imgSize, imgSize, 1), verbose=True)
    train(epochs=50)
    epoch += 1
    sess.close()
    save_models(askInp=False)
    np.save(os.path.join(modelPath, 'p.npy'), p) # save p value for future training if training on servers with time limits like Paperspace
# Out:
# 2024-08-13 13:08:25.566243: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8902
# 2024-08-13 13:08:25.578598: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# D(G(z)) (lower = better disc): -0.43810344
# D(x) (higher = better disc): -3.1055043
# D Loss: tf.Tensor(3.649644, shape=(), dtype=float32)
# G Loss: tf.Tensor(0.93636346, shape=(), dtype=float32)
#   0%|          | 0/45 [00:00<?, ?it/s]
# 2024-08-13 13:09:12.728934: W tensorflow/tsl/framework/bfc_allocator.cc:485] Allocator (GPU_0_bfc) ran out of memory trying to allocate 2.00GiB (rounded to 2147483648)requested by op Conv2D
# If the cause is memory fragmentation maybe the environment variable 'TF_GPU_ALLOCATOR=cuda_malloc_async' will improve the situation.
# Current allocation summary follows.
# Current allocation summary follows.
# 2024-08-13 13:09:12.729011: I tensorflow/tsl/framework/bfc_allocator.cc:1039] BFCAllocator dump for GPU_0_bfc
# 2024-08-13 13:09:12.729028: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (256): 	Total Chunks: 194, Chunks in use: 194. 48.5KiB allocated for chunks. 48.5KiB in use in bin. 14.5KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729038: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (512): 	Total Chunks: 177, Chunks in use: 177. 121.5KiB allocated for chunks. 121.5KiB in use in bin. 112.2KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729047: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1024): 	Total Chunks: 67, Chunks in use: 67. 97.0KiB allocated for chunks. 97.0KiB in use in bin. 93.8KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729055: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2048): 	Total Chunks: 37, Chunks in use: 37. 104.0KiB allocated for chunks. 104.0KiB in use in bin. 95.9KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729063: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4096): 	Total Chunks: 35, Chunks in use: 34. 156.0KiB allocated for chunks. 148.5KiB in use in bin. 138.7KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729072: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8192): 	Total Chunks: 6, Chunks in use: 5. 66.2KiB allocated for chunks. 55.2KiB in use in bin. 51.5KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729080: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16384): 	Total Chunks: 4, Chunks in use: 4. 79.5KiB allocated for chunks. 79.5KiB in use in bin. 66.3KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729088: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (32768): 	Total Chunks: 8, Chunks in use: 7. 359.0KiB allocated for chunks. 311.0KiB in use in bin. 260.0KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729096: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (65536): 	Total Chunks: 14, Chunks in use: 14. 996.0KiB allocated for chunks. 996.0KiB in use in bin. 932.5KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729105: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (131072): 	Total Chunks: 6, Chunks in use: 5. 1.00MiB allocated for chunks. 808.5KiB in use in bin. 738.6KiB client-requested in use in bin.
# 2024-08-13 13:09:12.729112: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (262144): 	Total Chunks: 19, Chunks in use: 16. 7.32MiB allocated for chunks. 6.03MiB in use in bin. 5.22MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729121: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (524288): 	Total Chunks: 42, Chunks in use: 40. 32.72MiB allocated for chunks. 31.41MiB in use in bin. 26.64MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729129: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (1048576): 	Total Chunks: 23, Chunks in use: 22. 36.17MiB allocated for chunks. 34.90MiB in use in bin. 28.84MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729137: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (2097152): 	Total Chunks: 22, Chunks in use: 21. 62.53MiB allocated for chunks. 59.49MiB in use in bin. 54.29MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729145: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (4194304): 	Total Chunks: 27, Chunks in use: 27. 126.92MiB allocated for chunks. 126.92MiB in use in bin. 113.04MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729153: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (8388608): 	Total Chunks: 4, Chunks in use: 4. 50.84MiB allocated for chunks. 50.84MiB in use in bin. 48.80MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729162: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (16777216): 	Total Chunks: 11, Chunks in use: 10. 267.90MiB allocated for chunks. 240.48MiB in use in bin. 234.03MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729177: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (33554432): 	Total Chunks: 10, Chunks in use: 7. 395.08MiB allocated for chunks. 249.03MiB in use in bin. 247.04MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729186: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (67108864): 	Total Chunks: 3, Chunks in use: 3. 208.00MiB allocated for chunks. 208.00MiB in use in bin. 176.00MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729194: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (134217728): 	Total Chunks: 2, Chunks in use: 1. 277.50MiB allocated for chunks. 128.00MiB in use in bin. 128.00MiB client-requested in use in bin.
# 2024-08-13 13:09:12.729202: I tensorflow/tsl/framework/bfc_allocator.cc:1046] Bin (268435456): 	Total Chunks: 7, Chunks in use: 6. 36.03GiB allocated for chunks. 34.62GiB in use in bin. 34.62GiB client-requested in use in bin.
# 2024-08-13 13:09:12.729210: I tensorflow/tsl/framework/bfc_allocator.cc:1062] Bin for 2.00GiB was 256.00MiB, Chunk State:
# 2024-08-13 13:09:12.729225: I tensorflow/tsl/framework/bfc_allocator.cc:1068]   Size: 1.42GiB | Requested Size: 97.68MiB | in_use: 0 | bin_num: 20, prev:   Size: 10.81GiB | Requested Size: 10.81GiB | in_use: 1 | bin_num: -1
# 2024-08-13 13:09:12.729231: I tensorflow/tsl/framework/bfc_allocator.cc:1075] Next region of size 40230584320
# 2024-08-13 13:09:12.729242: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ac2000000 of size 9248440320 next 1
# 2024-08-13 13:09:12.729249: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400000 of size 1280 next 2
# 2024-08-13 13:09:12.729258: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400500 of size 256 next 3
# 2024-08-13 13:09:12.729264: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400600 of size 256 next 4
# 2024-08-13 13:09:12.729269: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400700 of size 256 next 5
# 2024-08-13 13:09:12.729275: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400800 of size 256 next 6
# 2024-08-13 13:09:12.729280: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400900 of size 256 next 7
# 2024-08-13 13:09:12.729286: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400a00 of size 256 next 8
# 2024-08-13 13:09:12.729292: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9400b00 of size 4096 next 9
# 2024-08-13 13:09:12.729298: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9401b00 of size 256 next 10
# 2024-08-13 13:09:12.729304: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9401c00 of size 4096 next 11
# 2024-08-13 13:09:12.729309: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9402c00 of size 4096 next 12
# 2024-08-13 13:09:12.729315: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9403c00 of size 3612672 next 69
# 2024-08-13 13:09:12.729322: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9775c00 of size 4771840 next 13
# 2024-08-13 13:09:12.729328: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6ce9c02c00 of size 4194304 next 14
# 2024-08-13 13:09:12.729333: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea002c00 of size 4096 next 17
# 2024-08-13 13:09:12.729339: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea003c00 of size 4096 next 20
# 2024-08-13 13:09:12.729345: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea004c00 of size 4096 next 22
# 2024-08-13 13:09:12.729350: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea005c00 of size 4096 next 24
# 2024-08-13 13:09:12.729356: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea006c00 of size 4096 next 26
# 2024-08-13 13:09:12.729362: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea007c00 of size 4096 next 28
# 2024-08-13 13:09:12.729369: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea008c00 of size 256 next 29
# 2024-08-13 13:09:12.729375: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea008d00 of size 256 next 30
# 2024-08-13 13:09:12.729380: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea008e00 of size 256 next 32
# 2024-08-13 13:09:12.729395: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea008f00 of size 4096 next 33
# 2024-08-13 13:09:12.729401: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea009f00 of size 4608 next 35
# 2024-08-13 13:09:12.729406: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea00b100 of size 4096 next 36
# 2024-08-13 13:09:12.729412: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea00c100 of size 4096 next 40
# 2024-08-13 13:09:12.729418: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea00d100 of size 256 next 41
# 2024-08-13 13:09:12.729423: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea00d200 of size 4096 next 45
# 2024-08-13 13:09:12.729429: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea00e200 of size 4096 next 48
# 2024-08-13 13:09:12.729435: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea00f200 of size 4096 next 50
# 2024-08-13 13:09:12.729440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea010200 of size 4096 next 51
# 2024-08-13 13:09:12.729446: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea011200 of size 7936 next 42
# 2024-08-13 13:09:12.729452: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea013100 of size 12288 next 43
# 2024-08-13 13:09:12.729460: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea016100 of size 4096 next 55
# 2024-08-13 13:09:12.729466: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea017100 of size 4096 next 56
# 2024-08-13 13:09:12.729472: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea018100 of size 256 next 57
# 2024-08-13 13:09:12.729477: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea018200 of size 4096 next 61
# 2024-08-13 13:09:12.729483: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea019200 of size 3584 next 63
# 2024-08-13 13:09:12.729489: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea01a000 of size 4096 next 65
# 2024-08-13 13:09:12.729494: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea01b000 of size 3584 next 66
# 2024-08-13 13:09:12.729500: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea01be00 of size 3584 next 68
# 2024-08-13 13:09:12.729506: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea01cc00 of size 5376 next 58
# 2024-08-13 13:09:12.729512: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea01e100 of size 12288 next 59
# 2024-08-13 13:09:12.729517: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea021100 of size 3584 next 70
# 2024-08-13 13:09:12.729523: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea021f00 of size 256 next 71
# 2024-08-13 13:09:12.729529: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea022000 of size 3584 next 73
# 2024-08-13 13:09:12.729535: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea022e00 of size 3072 next 75
# 2024-08-13 13:09:12.729541: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea023a00 of size 3584 next 77
# 2024-08-13 13:09:12.729546: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea024800 of size 3072 next 78
# 2024-08-13 13:09:12.729552: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea025400 of size 3072 next 80
# 2024-08-13 13:09:12.729558: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea026000 of size 4864 next 72
# 2024-08-13 13:09:12.729564: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea027300 of size 19968 next 31
# 2024-08-13 13:09:12.729571: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea02c100 of size 65536 next 34
# 2024-08-13 13:09:12.729577: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea03c100 of size 3072 next 82
# 2024-08-13 13:09:12.729583: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea03cd00 of size 256 next 83
# 2024-08-13 13:09:12.729588: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea03ce00 of size 3072 next 87
# 2024-08-13 13:09:12.729594: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea03da00 of size 2560 next 88
# 2024-08-13 13:09:12.729600: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea03e400 of size 3072 next 91
# 2024-08-13 13:09:12.729606: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea03f000 of size 2560 next 92
# 2024-08-13 13:09:12.729611: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea03fa00 of size 2560 next 94
# 2024-08-13 13:09:12.729617: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea040400 of size 3840 next 84
# 2024-08-13 13:09:12.729624: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea041300 of size 8960 next 85
# 2024-08-13 13:09:12.729630: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea043600 of size 2560 next 96
# 2024-08-13 13:09:12.729636: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea044000 of size 256 next 97
# 2024-08-13 13:09:12.729642: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea044100 of size 2560 next 101
# 2024-08-13 13:09:12.729647: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea044b00 of size 2048 next 103
# 2024-08-13 13:09:12.729653: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea045300 of size 2560 next 104
# 2024-08-13 13:09:12.729659: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea045d00 of size 2048 next 105
# 2024-08-13 13:09:12.729665: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea046500 of size 2048 next 107
# 2024-08-13 13:09:12.729671: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea046d00 of size 3328 next 98
# 2024-08-13 13:09:12.729677: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea047a00 of size 7424 next 99
# 2024-08-13 13:09:12.729683: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea049700 of size 2048 next 109
# 2024-08-13 13:09:12.729688: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea049f00 of size 256 next 110
# 2024-08-13 13:09:12.729694: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04a000 of size 2048 next 115
# 2024-08-13 13:09:12.729700: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04a800 of size 1280 next 117
# 2024-08-13 13:09:12.729705: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04ad00 of size 2048 next 119
# 2024-08-13 13:09:12.729711: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04b500 of size 1280 next 120
# 2024-08-13 13:09:12.729717: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04ba00 of size 1280 next 123
# 2024-08-13 13:09:12.729722: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04bf00 of size 1280 next 125
# 2024-08-13 13:09:12.729728: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04c400 of size 1792 next 111
# 2024-08-13 13:09:12.729734: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04cb00 of size 5632 next 112
# 2024-08-13 13:09:12.729740: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04e100 of size 256 next 126
# 2024-08-13 13:09:12.729746: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04e200 of size 1280 next 129
# 2024-08-13 13:09:12.729753: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04e700 of size 768 next 131
# 2024-08-13 13:09:12.729759: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04ea00 of size 1280 next 133
# 2024-08-13 13:09:12.729766: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04ef00 of size 768 next 134
# 2024-08-13 13:09:12.729772: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04f200 of size 768 next 135
# 2024-08-13 13:09:12.729778: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04f500 of size 768 next 136
# 2024-08-13 13:09:12.729784: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04f800 of size 768 next 138
# 2024-08-13 13:09:12.729790: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04fb00 of size 256 next 139
# 2024-08-13 13:09:12.729796: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04fc00 of size 768 next 127
# 2024-08-13 13:09:12.729802: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea04ff00 of size 3840 next 128
# 2024-08-13 13:09:12.729808: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea050e00 of size 256 next 168
# 2024-08-13 13:09:12.729814: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea050f00 of size 256 next 162
# 2024-08-13 13:09:12.729820: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea051000 of size 512 next 163
# 2024-08-13 13:09:12.729826: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea051200 of size 1536 next 174
# 2024-08-13 13:09:12.729832: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea051800 of size 1280 next 178
# 2024-08-13 13:09:12.729838: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea051d00 of size 2560 next 179
# 2024-08-13 13:09:12.729844: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea052700 of size 2048 next 185
# 2024-08-13 13:09:12.729850: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea052f00 of size 3840 next 186
# 2024-08-13 13:09:12.729855: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea053e00 of size 2560 next 192
# 2024-08-13 13:09:12.729861: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054800 of size 256 next 217
# 2024-08-13 13:09:12.729867: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054900 of size 256 next 222
# 2024-08-13 13:09:12.729872: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054a00 of size 256 next 223
# 2024-08-13 13:09:12.729878: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054b00 of size 256 next 226
# 2024-08-13 13:09:12.729884: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054c00 of size 256 next 224
# 2024-08-13 13:09:12.729889: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054d00 of size 256 next 225
# 2024-08-13 13:09:12.729895: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054e00 of size 256 next 228
# 2024-08-13 13:09:12.729901: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea054f00 of size 256 next 229
# 2024-08-13 13:09:12.729907: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea055000 of size 256 next 231
# 2024-08-13 13:09:12.729912: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea055100 of size 256 next 165
# 2024-08-13 13:09:12.729918: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea055200 of size 8192 next 166
# 2024-08-13 13:09:12.729924: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057200 of size 256 next 230
# 2024-08-13 13:09:12.729930: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057300 of size 256 next 234
# 2024-08-13 13:09:12.729937: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057400 of size 256 next 235
# 2024-08-13 13:09:12.729942: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057500 of size 256 next 236
# 2024-08-13 13:09:12.729948: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057600 of size 256 next 237
# 2024-08-13 13:09:12.729954: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057700 of size 256 next 239
# 2024-08-13 13:09:12.729959: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057800 of size 256 next 240
# 2024-08-13 13:09:12.729965: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057900 of size 256 next 241
# 2024-08-13 13:09:12.729971: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057a00 of size 512 next 242
# 2024-08-13 13:09:12.729977: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057c00 of size 512 next 243
# 2024-08-13 13:09:12.729982: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea057e00 of size 512 next 246
# 2024-08-13 13:09:12.729988: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058000 of size 256 next 247
# 2024-08-13 13:09:12.729994: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058100 of size 256 next 248
# 2024-08-13 13:09:12.729999: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058200 of size 768 next 249
# 2024-08-13 13:09:12.730004: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058500 of size 768 next 250
# 2024-08-13 13:09:12.730008: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058800 of size 256 next 318
# 2024-08-13 13:09:12.730012: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058900 of size 256 next 321
# 2024-08-13 13:09:12.730015: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058a00 of size 256 next 251
# 2024-08-13 13:09:12.730018: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058b00 of size 256 next 253
# 2024-08-13 13:09:12.730021: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058c00 of size 256 next 254
# 2024-08-13 13:09:12.730024: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058d00 of size 256 next 257
# 2024-08-13 13:09:12.730027: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058e00 of size 256 next 255
# 2024-08-13 13:09:12.730029: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea058f00 of size 256 next 256
# 2024-08-13 13:09:12.730032: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea059000 of size 256 next 259
# 2024-08-13 13:09:12.730035: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea059100 of size 256 next 220
# 2024-08-13 13:09:12.730038: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea059200 of size 4096 next 221
# 2024-08-13 13:09:12.730041: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05a200 of size 256 next 666
# 2024-08-13 13:09:12.730044: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05a300 of size 512 next 667
# 2024-08-13 13:09:12.730047: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05a500 of size 768 next 668
# 2024-08-13 13:09:12.730049: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05a800 of size 512 next 346
# 2024-08-13 13:09:12.730052: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05aa00 of size 512 next 269
# 2024-08-13 13:09:12.730055: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05ac00 of size 512 next 349
# 2024-08-13 13:09:12.730058: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05ae00 of size 512 next 351
# 2024-08-13 13:09:12.730061: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05b000 of size 256 next 245
# 2024-08-13 13:09:12.730064: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05b100 of size 256 next 354
# 2024-08-13 13:09:12.730067: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05b200 of size 256 next 355
# 2024-08-13 13:09:12.730069: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05b300 of size 512 next 350
# 2024-08-13 13:09:12.730072: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05b500 of size 2304 next 357
# 2024-08-13 13:09:12.730075: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05be00 of size 256 next 358
# 2024-08-13 13:09:12.730079: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05bf00 of size 256 next 359
# 2024-08-13 13:09:12.730082: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05c000 of size 1536 next 360
# 2024-08-13 13:09:12.730085: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05c600 of size 1536 next 361
# 2024-08-13 13:09:12.730088: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05cc00 of size 768 next 418
# 2024-08-13 13:09:12.730091: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05cf00 of size 768 next 362
# 2024-08-13 13:09:12.730094: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05d200 of size 256 next 363
# 2024-08-13 13:09:12.730097: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05d300 of size 256 next 364
# 2024-08-13 13:09:12.730100: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05d400 of size 768 next 366
# 2024-08-13 13:09:12.730102: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05d700 of size 512 next 367
# 2024-08-13 13:09:12.730105: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05d900 of size 512 next 369
# 2024-08-13 13:09:12.730108: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05db00 of size 512 next 370
# 2024-08-13 13:09:12.730111: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05dd00 of size 512 next 371
# 2024-08-13 13:09:12.730114: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05df00 of size 512 next 374
# 2024-08-13 13:09:12.730117: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05e100 of size 256 next 375
# 2024-08-13 13:09:12.730120: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05e200 of size 256 next 376
# 2024-08-13 13:09:12.730122: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05e300 of size 768 next 379
# 2024-08-13 13:09:12.730125: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05e600 of size 768 next 377
# 2024-08-13 13:09:12.730128: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05e900 of size 768 next 378
# 2024-08-13 13:09:12.730131: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05ec00 of size 256 next 381
# 2024-08-13 13:09:12.730134: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05ed00 of size 256 next 382
# 2024-08-13 13:09:12.730137: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05ee00 of size 512 next 383
# 2024-08-13 13:09:12.730140: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05f000 of size 512 next 384
# 2024-08-13 13:09:12.730143: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05f200 of size 512 next 387
# 2024-08-13 13:09:12.730146: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05f400 of size 256 next 388
# 2024-08-13 13:09:12.730149: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05f500 of size 256 next 389
# 2024-08-13 13:09:12.730151: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05f600 of size 512 next 392
# 2024-08-13 13:09:12.730154: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05f800 of size 512 next 390
# 2024-08-13 13:09:12.730157: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05fa00 of size 512 next 391
# 2024-08-13 13:09:12.730160: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05fc00 of size 256 next 394
# 2024-08-13 13:09:12.730163: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05fd00 of size 256 next 395
# 2024-08-13 13:09:12.730166: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea05fe00 of size 768 next 396
# 2024-08-13 13:09:12.730170: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea060100 of size 768 next 397
# 2024-08-13 13:09:12.730173: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea060400 of size 768 next 400
# 2024-08-13 13:09:12.730177: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea060700 of size 512 next 401
# 2024-08-13 13:09:12.730180: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea060900 of size 512 next 402
# 2024-08-13 13:09:12.730183: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea060b00 of size 512 next 403
# 2024-08-13 13:09:12.730186: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea060d00 of size 512 next 406
# 2024-08-13 13:09:12.730188: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea060f00 of size 512 next 404
# 2024-08-13 13:09:12.730191: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea061100 of size 512 next 405
# 2024-08-13 13:09:12.730194: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea061300 of size 512 next 410
# 2024-08-13 13:09:12.730197: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea061500 of size 512 next 408
# 2024-08-13 13:09:12.730200: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea061700 of size 512 next 409
# 2024-08-13 13:09:12.730203: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea061900 of size 512 next 412
# 2024-08-13 13:09:12.730206: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea061b00 of size 512 next 413
# 2024-08-13 13:09:12.730209: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea061d00 of size 768 next 416
# 2024-08-13 13:09:12.730212: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea062000 of size 768 next 417
# 2024-08-13 13:09:12.730214: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea062300 of size 768 next 420
# 2024-08-13 13:09:12.730217: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea062600 of size 768 next 421
# 2024-08-13 13:09:12.730220: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea062900 of size 1280 next 150
# 2024-08-13 13:09:12.730223: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea062e00 of size 36864 next 151
# 2024-08-13 13:09:12.730226: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea06be00 of size 4096 next 195
# 2024-08-13 13:09:12.730229: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea06ce00 of size 3072 next 199
# 2024-08-13 13:09:12.730232: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea06da00 of size 4096 next 201
# 2024-08-13 13:09:12.730235: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea06ea00 of size 3584 next 203
# 2024-08-13 13:09:12.730238: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea06f800 of size 4096 next 206
# 2024-08-13 13:09:12.730241: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea070800 of size 4096 next 211
# 2024-08-13 13:09:12.730244: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea071800 of size 4096 next 213
# 2024-08-13 13:09:12.730247: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea072800 of size 4096 next 216
# 2024-08-13 13:09:12.730250: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea073800 of size 5632 next 164
# 2024-08-13 13:09:12.730253: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea074e00 of size 36864 next 167
# 2024-08-13 13:09:12.730256: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07de00 of size 256 next 262
# 2024-08-13 13:09:12.730259: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07df00 of size 256 next 260
# 2024-08-13 13:09:12.730261: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e000 of size 256 next 261
# 2024-08-13 13:09:12.730265: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e100 of size 256 next 264
# 2024-08-13 13:09:12.730267: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e200 of size 256 next 265
# 2024-08-13 13:09:12.730270: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e300 of size 256 next 266
# 2024-08-13 13:09:12.730275: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e400 of size 256 next 267
# 2024-08-13 13:09:12.730278: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e500 of size 256 next 268
# 2024-08-13 13:09:12.730281: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e600 of size 256 next 272
# 2024-08-13 13:09:12.730283: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e700 of size 256 next 270
# 2024-08-13 13:09:12.730286: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e800 of size 256 next 271
# 2024-08-13 13:09:12.730289: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07e900 of size 256 next 274
# 2024-08-13 13:09:12.730292: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07ea00 of size 256 next 275
# 2024-08-13 13:09:12.730295: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07eb00 of size 512 next 276
# 2024-08-13 13:09:12.730298: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07ed00 of size 512 next 277
# 2024-08-13 13:09:12.730301: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07ef00 of size 512 next 278
# 2024-08-13 13:09:12.730303: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07f100 of size 256 next 280
# 2024-08-13 13:09:12.730306: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07f200 of size 256 next 281
# 2024-08-13 13:09:12.730309: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07f300 of size 512 next 284
# 2024-08-13 13:09:12.730312: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07f500 of size 512 next 282
# 2024-08-13 13:09:12.730315: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07f700 of size 512 next 283
# 2024-08-13 13:09:12.730318: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07f900 of size 256 next 287
# 2024-08-13 13:09:12.730321: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07fa00 of size 256 next 288
# 2024-08-13 13:09:12.730323: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07fb00 of size 256 next 289
# 2024-08-13 13:09:12.730326: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07fc00 of size 256 next 290
# 2024-08-13 13:09:12.730329: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07fd00 of size 256 next 292
# 2024-08-13 13:09:12.730332: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07fe00 of size 256 next 293
# 2024-08-13 13:09:12.730335: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea07ff00 of size 256 next 294
# 2024-08-13 13:09:12.730338: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080000 of size 256 next 295
# 2024-08-13 13:09:12.730341: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080100 of size 256 next 296
# 2024-08-13 13:09:12.730343: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080200 of size 256 next 299
# 2024-08-13 13:09:12.730346: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080300 of size 256 next 300
# 2024-08-13 13:09:12.730349: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080400 of size 256 next 301
# 2024-08-13 13:09:12.730352: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080500 of size 256 next 302
# 2024-08-13 13:09:12.730355: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080600 of size 256 next 303
# 2024-08-13 13:09:12.730358: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080700 of size 256 next 304
# 2024-08-13 13:09:12.730360: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080800 of size 256 next 305
# 2024-08-13 13:09:12.730363: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080900 of size 256 next 306
# 2024-08-13 13:09:12.730366: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080a00 of size 256 next 307
# 2024-08-13 13:09:12.730370: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080b00 of size 256 next 309
# 2024-08-13 13:09:12.730373: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080c00 of size 256 next 310
# 2024-08-13 13:09:12.730376: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080d00 of size 256 next 312
# 2024-08-13 13:09:12.730379: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea080e00 of size 512 next 313
# 2024-08-13 13:09:12.730382: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081000 of size 512 next 314
# 2024-08-13 13:09:12.730385: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081200 of size 512 next 316
# 2024-08-13 13:09:12.730388: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081400 of size 512 next 319
# 2024-08-13 13:09:12.730391: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081600 of size 512 next 317
# 2024-08-13 13:09:12.730393: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081800 of size 512 next 320
# 2024-08-13 13:09:12.730396: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081a00 of size 768 next 324
# 2024-08-13 13:09:12.730399: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081d00 of size 256 next 325
# 2024-08-13 13:09:12.730402: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081e00 of size 256 next 326
# 2024-08-13 13:09:12.730405: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea081f00 of size 256 next 327
# 2024-08-13 13:09:12.730408: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082000 of size 256 next 328
# 2024-08-13 13:09:12.730410: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082100 of size 256 next 329
# 2024-08-13 13:09:12.730413: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082200 of size 256 next 331
# 2024-08-13 13:09:12.730416: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082300 of size 256 next 332
# 2024-08-13 13:09:12.730419: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082400 of size 256 next 333
# 2024-08-13 13:09:12.730422: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082500 of size 256 next 334
# 2024-08-13 13:09:12.730425: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082600 of size 256 next 335
# 2024-08-13 13:09:12.730428: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082700 of size 256 next 336
# 2024-08-13 13:09:12.730431: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082800 of size 256 next 337
# 2024-08-13 13:09:12.730434: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082900 of size 256 next 340
# 2024-08-13 13:09:12.730437: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082a00 of size 256 next 341
# 2024-08-13 13:09:12.730440: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082b00 of size 256 next 342
# 2024-08-13 13:09:12.730442: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082c00 of size 256 next 345
# 2024-08-13 13:09:12.730445: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea082d00 of size 768 next 422
# 2024-08-13 13:09:12.730448: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea083000 of size 768 next 424
# 2024-08-13 13:09:12.730451: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea083300 of size 768 next 425
# 2024-08-13 13:09:12.730454: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea083600 of size 768 next 291
# 2024-08-13 13:09:12.730457: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea083900 of size 768 next 482
# 2024-08-13 13:09:12.730460: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea083c00 of size 1280 next 508
# 2024-08-13 13:09:12.730463: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea084100 of size 1792 next 414
# 2024-08-13 13:09:12.730467: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea084800 of size 1792 next 582
# 2024-08-13 13:09:12.730470: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea084f00 of size 256 next 690
# 2024-08-13 13:09:12.730473: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085000 of size 256 next 685
# 2024-08-13 13:09:12.730476: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085100 of size 256 next 688
# 2024-08-13 13:09:12.730479: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085200 of size 256 next 686
# 2024-08-13 13:09:12.730482: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085300 of size 256 next 693
# 2024-08-13 13:09:12.730485: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085400 of size 256 next 348
# 2024-08-13 13:09:12.730487: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085500 of size 256 next 695
# 2024-08-13 13:09:12.730490: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085600 of size 256 next 677
# 2024-08-13 13:09:12.730493: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085700 of size 256 next 687
# 2024-08-13 13:09:12.730496: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085800 of size 256 next 696
# 2024-08-13 13:09:12.730499: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085900 of size 256 next 692
# 2024-08-13 13:09:12.730502: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085a00 of size 256 next 694
# 2024-08-13 13:09:12.730505: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085b00 of size 256 next 689
# 2024-08-13 13:09:12.730507: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085c00 of size 256 next 699
# 2024-08-13 13:09:12.730510: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085d00 of size 256 next 698
# 2024-08-13 13:09:12.730513: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085e00 of size 256 next 697
# 2024-08-13 13:09:12.730516: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea085f00 of size 256 next 670
# 2024-08-13 13:09:12.730519: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea086000 of size 256 next 701
# 2024-08-13 13:09:12.730522: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea086100 of size 256 next 704
# 2024-08-13 13:09:12.730524: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea086200 of size 256 next 703
# 2024-08-13 13:09:12.730527: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea086300 of size 256 next 702
# 2024-08-13 13:09:12.730530: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea086400 of size 2048 next 708
# 2024-08-13 13:09:12.730533: I tensorflow/tsl/framework/bfc_allocator.cc:1095] Free  at 7f6cea086c00 of size 7680 next 427
# 2024-08-13 13:09:12.730536: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea088a00 of size 256 next 428
# 2024-08-13 13:09:12.730540: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea088b00 of size 256 next 429
# 2024-08-13 13:09:12.730542: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea088c00 of size 768 next 430
# 2024-08-13 13:09:12.730546: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea088f00 of size 768 next 431
# 2024-08-13 13:09:12.730549: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea089200 of size 768 next 433
# 2024-08-13 13:09:12.730552: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea089500 of size 768 next 434
# 2024-08-13 13:09:12.730555: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea089800 of size 768 next 435
# 2024-08-13 13:09:12.730558: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea089b00 of size 768 next 437
# 2024-08-13 13:09:12.730561: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea089e00 of size 256 next 438
# 2024-08-13 13:09:12.730565: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea089f00 of size 256 next 439
# 2024-08-13 13:09:12.730568: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08a000 of size 768 next 440
# 2024-08-13 13:09:12.730571: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08a300 of size 768 next 441
# 2024-08-13 13:09:12.730574: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08a600 of size 768 next 444
# 2024-08-13 13:09:12.730577: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08a900 of size 768 next 445
# 2024-08-13 13:09:12.730580: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08ac00 of size 768 next 446
# 2024-08-13 13:09:12.730583: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08af00 of size 768 next 447
# 2024-08-13 13:09:12.730586: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08b200 of size 768 next 448
# 2024-08-13 13:09:12.730589: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08b500 of size 768 next 449
# 2024-08-13 13:09:12.730592: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08b800 of size 768 next 451
# 2024-08-13 13:09:12.730595: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08bb00 of size 768 next 452
# 2024-08-13 13:09:12.730598: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08be00 of size 768 next 453
# 2024-08-13 13:09:12.730601: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08c100 of size 768 next 455
# 2024-08-13 13:09:12.730603: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08c400 of size 768 next 456
# 2024-08-13 13:09:12.730606: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08c700 of size 768 next 457
# 2024-08-13 13:09:12.730609: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08ca00 of size 768 next 459
# 2024-08-13 13:09:12.730612: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08cd00 of size 768 next 460
# 2024-08-13 13:09:12.730615: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08d000 of size 768 next 461
# 2024-08-13 13:09:12.730618: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08d300 of size 768 next 464
# 2024-08-13 13:09:12.730621: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08d600 of size 768 next 465
# 2024-08-13 13:09:12.730623: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08d900 of size 768 next 466
# 2024-08-13 13:09:12.730626: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08dc00 of size 768 next 467
# 2024-08-13 13:09:12.730629: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08df00 of size 768 next 468
# 2024-08-13 13:09:12.730632: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08e200 of size 768 next 469
# 2024-08-13 13:09:12.730635: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08e500 of size 768 next 470
# 2024-08-13 13:09:12.730638: I tensorflow/tsl/framework/bfc_allocator.cc:1095] InUse at 7f6cea08e800 of size 768 next 471
# ...
# 2024-08-13 13:09:12.731855: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 24576 totalling 24.0KiB
# 2024-08-13 13:09:12.731858: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 36864 totalling 108.0KiB
# 2024-08-13 13:09:12.731861: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 48128 totalling 47.0KiB
# 2024-08-13 13:09:12.731865: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 49152 totalling 96.0KiB
# 2024-08-13 13:09:12.731868: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 61440 totalling 60.0KiB
# 2024-08-13 13:09:12.731871: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 7 Chunks of size 65536 totalling 448.0KiB
# 2024-08-13 13:09:12.731875: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 73728 totalling 360.0KiB
# 2024-08-13 13:09:12.731878: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 88576 totalling 86.5KiB
# 2024-08-13 13:09:12.731881: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 103936 totalling 101.5KiB
# 2024-08-13 13:09:12.731885: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 131072 totalling 256.0KiB
# 2024-08-13 13:09:12.731888: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 143872 totalling 140.5KiB
# 2024-08-13 13:09:12.731891: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 200704 totalling 196.0KiB
# 2024-08-13 13:09:12.731895: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 221184 totalling 216.0KiB
# 2024-08-13 13:09:12.731898: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 307200 totalling 600.0KiB
# 2024-08-13 13:09:12.731901: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 309760 totalling 302.5KiB
# 2024-08-13 13:09:12.731905: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 331776 totalling 972.0KiB
# 2024-08-13 13:09:12.731908: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 356352 totalling 348.0KiB
# 2024-08-13 13:09:12.731911: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 393216 totalling 384.0KiB
# 2024-08-13 13:09:12.731915: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 398592 totalling 389.2KiB
# 2024-08-13 13:09:12.731918: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 442368 totalling 432.0KiB
# 2024-08-13 13:09:12.731921: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 4 Chunks of size 458752 totalling 1.75MiB
# 2024-08-13 13:09:12.731925: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 491520 totalling 960.0KiB
# 2024-08-13 13:09:12.731928: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 552960 totalling 540.0KiB
# 2024-08-13 13:09:12.731931: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 589824 totalling 1.12MiB
# 2024-08-13 13:09:12.731934: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 667136 totalling 651.5KiB
# 2024-08-13 13:09:12.731938: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 688128 totalling 1.97MiB
# 2024-08-13 13:09:12.731941: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 708608 totalling 1.35MiB
# 2024-08-13 13:09:12.731944: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 9 Chunks of size 716800 totalling 6.15MiB
# 2024-08-13 13:09:12.731947: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 786432 totalling 1.50MiB
# 2024-08-13 13:09:12.731951: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 790272 totalling 771.8KiB
# 2024-08-13 13:09:12.731954: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 6 Chunks of size 860160 totalling 4.92MiB
# 2024-08-13 13:09:12.731957: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 884480 totalling 863.8KiB
# 2024-08-13 13:09:12.731960: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 884736 totalling 864.0KiB
# 2024-08-13 13:09:12.731964: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 986624 totalling 963.5KiB
# 2024-08-13 13:09:12.731967: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 10 Chunks of size 1032192 totalling 9.84MiB
# 2024-08-13 13:09:12.731970: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1081344 totalling 1.03MiB
# 2024-08-13 13:09:12.731974: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1090816 totalling 1.04MiB
# 2024-08-13 13:09:12.731977: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1132800 totalling 1.08MiB
# 2024-08-13 13:09:12.731980: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1146880 totalling 1.09MiB
# 2024-08-13 13:09:12.731983: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 1290240 totalling 2.46MiB
# 2024-08-13 13:09:12.731986: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1327104 totalling 1.27MiB
# 2024-08-13 13:09:12.731990: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1720320 totalling 1.64MiB
# 2024-08-13 13:09:12.731993: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 1769472 totalling 8.44MiB
# 2024-08-13 13:09:12.731996: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 1871872 totalling 3.57MiB
# 2024-08-13 13:09:12.731999: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1900544 totalling 1.81MiB
# 2024-08-13 13:09:12.732003: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1961984 totalling 1.87MiB
# 2024-08-13 13:09:12.732006: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 1966080 totalling 3.75MiB
# 2024-08-13 13:09:12.732009: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2020352 totalling 1.93MiB
# 2024-08-13 13:09:12.732012: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2032896 totalling 1.94MiB
# 2024-08-13 13:09:12.732016: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2076672 totalling 1.98MiB
# 2024-08-13 13:09:12.732019: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2155008 totalling 2.05MiB
# 2024-08-13 13:09:12.732022: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 2293760 totalling 4.38MiB
# 2024-08-13 13:09:12.732025: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2303488 totalling 2.20MiB
# 2024-08-13 13:09:12.732028: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 2449408 totalling 4.67MiB
# 2024-08-13 13:09:12.732032: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2483712 totalling 2.37MiB
# 2024-08-13 13:09:12.732035: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 2621440 totalling 5.00MiB
# 2024-08-13 13:09:12.732038: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 3 Chunks of size 3031040 totalling 8.67MiB
# 2024-08-13 13:09:12.732041: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 3145728 totalling 6.00MiB
# 2024-08-13 13:09:12.732045: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3188736 totalling 3.04MiB
# 2024-08-13 13:09:12.732048: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3572224 totalling 3.41MiB
# 2024-08-13 13:09:12.732051: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 3612672 totalling 6.89MiB
# 2024-08-13 13:09:12.732054: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3670016 totalling 3.50MiB
# 2024-08-13 13:09:12.732057: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3743744 totalling 3.57MiB
# 2024-08-13 13:09:12.732061: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 3923712 totalling 3.74MiB
# 2024-08-13 13:09:12.732064: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 16 Chunks of size 4194304 totalling 64.00MiB
# 2024-08-13 13:09:12.732067: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4317184 totalling 4.12MiB
# 2024-08-13 13:09:12.732071: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4423680 totalling 4.22MiB
# 2024-08-13 13:09:12.732074: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4472832 totalling 4.27MiB
# 2024-08-13 13:09:12.732077: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 4771840 totalling 4.55MiB
# 2024-08-13 13:09:12.732080: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 5029888 totalling 4.80MiB
# 2024-08-13 13:09:12.732083: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6193152 totalling 5.91MiB
# 2024-08-13 13:09:12.732087: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 6621184 totalling 6.31MiB
# 2024-08-13 13:09:12.732090: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7144448 totalling 6.81MiB
# 2024-08-13 13:09:12.732093: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7518720 totalling 7.17MiB
# 2024-08-13 13:09:12.732096: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7691520 totalling 7.33MiB
# 2024-08-13 13:09:12.732099: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 7791104 totalling 7.43MiB
# 2024-08-13 13:09:12.732103: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 10364928 totalling 9.88MiB
# 2024-08-13 13:09:12.732106: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 11979520 totalling 11.42MiB
# 2024-08-13 13:09:12.732109: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 15037184 totalling 14.34MiB
# 2024-08-13 13:09:12.732113: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 15930880 totalling 15.19MiB
# 2024-08-13 13:09:12.732116: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 19640064 totalling 18.73MiB
# 2024-08-13 13:09:12.732119: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 19676672 totalling 18.76MiB
# 2024-08-13 13:09:12.732123: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 19713792 totalling 18.80MiB
# 2024-08-13 13:09:12.732126: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 22044672 totalling 21.02MiB
# 2024-08-13 13:09:12.732129: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 23496704 totalling 22.41MiB
# 2024-08-13 13:09:12.732133: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 27279360 totalling 52.03MiB
# 2024-08-13 13:09:12.732136: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 28005376 totalling 26.71MiB
# 2024-08-13 13:09:12.732139: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 32514048 totalling 62.02MiB
# 2024-08-13 13:09:12.732143: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 34594816 totalling 32.99MiB
# 2024-08-13 13:09:12.732146: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 5 Chunks of size 37748736 totalling 180.00MiB
# 2024-08-13 13:09:12.732149: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 37785600 totalling 36.04MiB
# 2024-08-13 13:09:12.732153: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 67108864 totalling 128.00MiB
# 2024-08-13 13:09:12.732156: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 83886080 totalling 80.00MiB
# 2024-08-13 13:09:12.732159: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 134217728 totalling 128.00MiB
# 2024-08-13 13:09:12.732163: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 479199232 totalling 457.00MiB
# 2024-08-13 13:09:12.732166: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 1321205760 totalling 1.23GiB
# 2024-08-13 13:09:12.732169: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 2902458368 totalling 2.70GiB
# 2024-08-13 13:09:12.732173: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 1 Chunks of size 9248440320 totalling 8.61GiB
# 2024-08-13 13:09:12.732176: I tensorflow/tsl/framework/bfc_allocator.cc:1103] 2 Chunks of size 11609833472 totalling 21.62GiB
# 2024-08-13 13:09:12.732179: I tensorflow/tsl/framework/bfc_allocator.cc:1107] Sum Total of in-use chunks: 35.73GiB
# 2024-08-13 13:09:12.732183: I tensorflow/tsl/framework/bfc_allocator.cc:1109] Total bytes in pool: 40230584320 memory_limit_: 40230584320 available bytes: 0 curr_region_allocation_bytes_: 80461168640
# 2024-08-13 13:09:12.732191: I tensorflow/tsl/framework/bfc_allocator.cc:1114] Stats:
# Limit:                     40230584320
# InUse:                     38364051200
# MaxInUse:                  38367239936
# NumAllocs:                        4561
# MaxAllocSize:              11609833472
# Reserved:                            0
# PeakReserved:                        0
# LargestFreeBlock:                    0
#
# 2024-08-13 13:09:12.732208: W tensorflow/tsl/framework/bfc_allocator.cc:497] *************************************************************************************************___
# 2024-08-13 13:09:12.732240: W tensorflow/core/framework/op_kernel.cc:1830] OP_REQUIRES failed at conv_ops.cc:629 : RESOURCE_EXHAUSTED: OOM when allocating tensor with shape[1,512,1024,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# Cell In[18], line 8
#       6 while True:
#       7     sess = timeIt('Training')
# ----> 8     display(z1=npr.randn(rows * cols, zdim), z2=npr.randn(rows * cols, zdim), noise=npr.randn(rows * cols, imgSize, imgSize, 1), verbose=True)
#       9     train(epochs=50)
#      10     epoch += 1
#
# Cell In[16], line 64, in display(z1, z2, noise, verbose)
#      61 plt.show()
#      63 if verbose[0]:
# ---> 64     fid = round(calculate_fid(), 4)
#      65     print('FID:', fid)
#      66     fids.append(fid)
#
# Cell In[12], line 51, in calculate_fid()
#      49 for batchS in tqdm(range(0, expandM, bs)):
#      50     batch = reals[batchS: batchS + bs]
# ---> 51     fakeFeatures, realFeatures = crunchFunc(batch, bs=bs)
#      52     allFakeFeatures[batchS: batchS + bs] = fakeFeatures
#      54     if crunchFunc == crunch:
#
# Cell In[12], line 26, in calculate_fid.<locals>.crunch(batch, bs)
#      24 w2 = mapper(z2, training=False)
#      25 ws = [w1 for _ in range(w1_range)] + [w2 for _ in range(w2_range)]
# ---> 26 fakes = generator([*ws, noise], training=False)
#      27 fakeFeatures = inception(fakes/2+0.5, training=False)
#      28 realFeatures = inception(batch/2+0.5, training=False)
#
# File ~/anaconda3/envs/LeeYS/lib/python3.9/site-packages/keras/utils/traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# Cell In[2], line 153, in ConvMod.call(self, inputs)
#     150 # B, k, k, i, o -> k, k, i, B, o -> k, k, i, (B*o)
#     151 wpp = tf.reshape(tf.transpose(wpp, [1, 2, 3, 0, 4]), [wpp.shape[1], wpp.shape[2], wpp.shape[3], -1])
# --> 153 x = tf.nn.conv2d(x, wpp, padding='SAME', data_format='NCHW', strides=[1, 1, 1, 1]) # grouped conv
#     154 x = tf.reshape(x, (-1, self.nf, x.shape[2], x.shape[3])) # 1, (N*C), H, W -> N, C, H, W
#     155 x = tf.transpose(x, (0, 2, 3, 1)) # NCHW -> NHWC
#
# ResourceExhaustedError: Exception encountered when calling layer 'conv_mod_23' (type ConvMod).
#
# {{function_node __wrapped__Conv2D_device_/job:localhost/replica:0/task:0/device:GPU:0}} OOM when allocating tensor with shape[1,512,1024,1024] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc [Op:Conv2D]
#
# Call arguments received by layer 'conv_mod_23' (type ConvMod):
#   • inputs=['tf.Tensor(shape=(16, 1024, 1024, 173), dtype=float32)', 'tf.Tensor(shape=(16, 1024), dtype=float32)']

# %% [markdown]
# Visualize gradients

# %%
if type(reals) != np.ndarray or type(ds) == type(None):
    #loadData()
    reals = np.load(os.path.join(datasetPath, 'imgs.npy'))
    m = batchSize * (reals.shape[0] // batchSize)
    reals = reals[:m].astype(np.float32)

    assert reals.shape[0] % batchSize == 0
    assert type(reals) == np.ndarray
    ds = (tf.data.Dataset.from_tensor_slices(tf.cast(reals, tf.float32)).shuffle(3000).batch(batchSize))
    ds = ds.prefetch(AUTO)
    gc.collect()

dGrad, gGrad, dNorm, gNorm, img, fake, truePreds, fakePreds = retGrads()
dGrad = np.sum(dGrad, axis=2)
gGrad = np.sum(gGrad, axis=2)
print('D(x): {} | D(G(z)): {}'.format(truePreds, fakePreds))
fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 20))
dGrad = (dGrad - np.min(dGrad)) / (np.max(dGrad) - np.min(dGrad) + eps)
gGrad = (gGrad - np.min(gGrad)) / (np.max(gGrad) - np.min(gGrad) + eps)
axes[0][0].imshow(img/2+0.5)
axes[0][1].imshow(fake/2+0.5)
axes[1][0].imshow(dGrad)
axes[1][0].set_title('Real Grad; Norm: {}'.format(round(dNorm, 4)))
axes[1][1].imshow(gGrad)
axes[1][1].set_title('Fake Grad; Norm: {}'.format(round(gNorm, 4)))
plt.show()

# %% [markdown]
# Visualize mapping activations

# %%
z = npr.randn(1, zdim)
w = mapper.predict(z)
plt.imshow(z[0].reshape(16, 16))
plt.colorbar()
plt.show()
plt.imshow(w[0].reshape(16, 16))
plt.colorbar()
plt.show()

# %% [markdown]
# See generated images

# %%
try:
    constZ1s
except Exception as e:
    constZ1s = npr.randn(rows*cols, zdim)
    constZ2s = npr.randn(rows*cols, zdim)
    constNoises = npr.randn(rows * cols, imgSize, imgSize, 1)

'''
if z1s commented out, same content, different styles
if z2s commented out, different content, same styles
if noise = 0, undesirably smooth faces but just a test to make sure styles are working properly
'''
for i in range(1): 
    constZ1s = npr.randn(rows * cols, zdim)
    #constZ2s = npr.randn(rows * cols, zdim)
    constNoises = npr.randn(rows * cols, imgSize, imgSize, 1) * 0
    pred11=display(z1=constZ1s, z2=constZ2s, noise=constNoises, verbose=False)

# %%
try:
    constZ1s
except Exception as e:
    constZ1s = npr.randn(rows*cols, zdim)
    constZ2s = npr.randn(rows*cols, zdim)
    constNoises = npr.randn(rows * cols, imgSize, imgSize, 1)
    
fig, axes = plt.subplots(nrows=2, ncols=cols, figsize=(30, 15))

z1 = constZ1s; z2 = constZ2s; noise = constNoises

randInds = npr.randint(0, reals.shape[0], (rows*cols,))

w1 = z1; w2 = z2
ws = [w1 for i in range(3)] + [w2 for i in range(4)]
preds = generator([*ws, noise], training=False)

for i in range(cols):
    axes[0][i].imshow(preds[i] / 2 + 0.5)
    
w1 = mapper(z1, training=False)
w2 = mapper(z2, training=False)
ws = [w1 for i in range(3)] + [w2 for i in range(4)]
preds = generator([*ws, noise], training=False)

for i in range(cols):
    axes[1][i].imshow(preds[i] / 2 + 0.5)

plt.show()

# %% [markdown]
# See metrics over training

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20, 4))
pltX = range(len(dcosts))
axes[0].plot(pltX, dcosts); axes[0].set_title('D Loss')
axes[1].plot(pltX, gcosts); axes[1].set_title('G Loss')
axes[2].plot(pltX, gpcosts); axes[2].set_title('GP')
plt.show()

fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(20, 4))
axes[0].plot(pltX, ps); axes[0].set_title('Evolution of P(aug) over training')
axes[1].plot(pltX, rts); axes[1].set_title('Evolution of r_t')
plt.show()

fig, axes = plt.subplots(nrows=1, ncols=1, figsize=(20, 8))
axes.set_title('D Loss (Blue) vs. G Loss (Orange)')
axes.plot(pltX, dcosts, color='blue')
axes.plot(pltX, gcosts, color='orange')
plt.show()
